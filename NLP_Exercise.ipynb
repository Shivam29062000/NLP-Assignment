# %% [markdown]
# **NLP Pipeline**

# %%
# !pip install textacy
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      |████████████████████████████████| 777.4 MB 5.7 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
import textacy
nlp=spacy.load('en_core_web_lg')
f=open('text.txt','rt')
data=f.read()
doc=nlp(data)
doc
# Out:
# I chose my topic to be the Penguin because, like I said, I think they look really cute. I think they look really cute because they have such a big head and a short, thick neck. Also the way they waddle, is really cute. The way they stand, really fascinates me. They look really proud. I sometimes wish I was as proud as they look.
# Penguins are birds that can't fly, but they are really good swimmers. This means they spend most of their life in the water. However, they lay their eggs on the land, and raise their babies there as well.
# ...

# %% [markdown]
# Segmentation:

# %%
sentences=list(doc.sents)
sentences
# Out:
# [I chose my topic to be the Penguin because, like I said, I think they look really cute.,
#  I think they look really cute because they have such a big head and a short, thick neck.,
#  Also the way they waddle, is really cute.,
#  The way they stand, really fascinates me.,
#  They look really proud.,
#  I sometimes wish I was as proud as they look.,
#
#  Penguins are birds that can't fly, but they are really good swimmers.,
#  This means they spend most of their life in the water.,
#  However, they lay their eggs on the land, and raise their babies there as well.,
#
#  All Penguins have a big head an a short and thick neck.,
#  Their body are streamlined, with a short tail.,
#  Penguins have heavy bones, which allows them to stay in the water.,
#  Penguins dive into they water and 'fly' underwater at great speed.,
#  Penguins have a light colour skin on their belly, but a darker colour skin on their back, which helps them camouflage them underwater.,
# ...

# %% [markdown]
# Tokenization:

# %%
import os
import nltk
import nltk.corpus

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
data_tokens=word_tokenize(data)
data_tokens
# Out:
# ['I',
#  'chose',
#  'my',
#  'topic',
#  'to',
#  'be',
#  'the',
#  'Penguin',
#  'because',
#  ',',
#  'like',
#  'I',
#  'said',
#  ',',
#  'I',
#  'think',
#  'they',
#  'look',
#  'really',
#  'cute',
#  '.',
#  'I',
#  'think',
#  'they',
#  'look',
#  'really',
#  'cute',
#  'because',
#  'they',
#  'have',
#  'such',
#  'a',
#  'big',
#  'head',
#  'and',
#  'a',
#  'short',
#  ',',
#  'thick',
#  'neck',
#  '.',
#  'Also',
#  'the',
#  'way',
#  'they',
#  'waddle',
#  ',',
#  'is',
#  'really',
#  'cute',
#  '.',
#  'The',
#  'way',
#  'they',
#  'stand',
#  ',',
#  'really',
#  'fascinates',
#  'me',
#  '.',
#  'They',
#  'look',
#  'really',
#  'proud',
#  '.',
#  'I',
#  'sometimes',
#  'wish',
#  'I',
#  'was',
#  'as',
#  'proud',
#  'as',
#  'they',
#  'look',
#  '.',
#  'Penguins',
#  'are',
#  'birds',
#  'that',
#  'ca',
#  "n't",
#  'fly',
#  ',',
#  'but',
#  'they',
#  'are',
#  'really',
#  'good',
#  'swimmers',
#  '.',
#  'This',
#  'means',
#  'they',
# ...

# %%
len(data_tokens)
# Out:
# 475

# %% [markdown]
# POS Tagging:

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos=nltk.pos_tag(data_tokens)
pos
# Out:
# [('I', 'PRP'),
#  ('chose', 'VBD'),
#  ('my', 'PRP$'),
#  ('topic', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('the', 'DT'),
#  ('Penguin', 'NNP'),
#  ('because', 'IN'),
#  (',', ','),
#  ('like', 'IN'),
#  ('I', 'PRP'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('they', 'PRP'),
#  ('look', 'VBP'),
#  ('really', 'RB'),
#  ('cute', 'JJ'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('they', 'PRP'),
#  ('look', 'VBP'),
#  ('really', 'RB'),
#  ('cute', 'JJ'),
#  ('because', 'IN'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('such', 'PDT'),
#  ('a', 'DT'),
#  ('big', 'JJ'),
#  ('head', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('short', 'JJ'),
#  (',', ','),
#  ('thick', 'JJ'),
#  ('neck', 'NN'),
#  ('.', '.'),
#  ('Also', 'RB'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('they', 'PRP'),
#  ('waddle', 'VBP'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('really', 'RB'),
#  ('cute', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('way', 'NN'),
# ...

# %% [markdown]
# Stemming:

# %%
from nltk.stem import PorterStemmer
pst=PorterStemmer()

# %%
st=list()
for word in data_tokens:
  st.append(pst.stem(word))
st
# Out:
# ['I',
#  'chose',
#  'my',
#  'topic',
#  'to',
#  'be',
#  'the',
#  'penguin',
#  'becaus',
#  ',',
#  'like',
#  'I',
#  'said',
#  ',',
#  'I',
#  'think',
#  'they',
#  'look',
#  'realli',
#  'cute',
#  '.',
#  'I',
#  'think',
#  'they',
#  'look',
#  'realli',
#  'cute',
#  'becaus',
#  'they',
#  'have',
#  'such',
#  'a',
#  'big',
#  'head',
#  'and',
#  'a',
#  'short',
#  ',',
#  'thick',
#  'neck',
#  '.',
#  'also',
#  'the',
#  'way',
#  'they',
#  'waddl',
#  ',',
#  'is',
#  'realli',
#  'cute',
#  '.',
#  'the',
#  'way',
#  'they',
#  'stand',
#  ',',
#  'realli',
#  'fascin',
#  'me',
#  '.',
#  'they',
#  'look',
#  'realli',
#  'proud',
#  '.',
#  'I',
#  'sometim',
#  'wish',
#  'I',
#  'wa',
#  'as',
#  'proud',
#  'as',
#  'they',
#  'look',
#  '.',
#  'penguin',
#  'are',
#  'bird',
#  'that',
#  'ca',
#  "n't",
#  'fli',
#  ',',
#  'but',
#  'they',
#  'are',
#  'realli',
#  'good',
#  'swimmer',
#  '.',
#  'thi',
#  'mean',
#  'they',
#  'spend',
# ...

# %% [markdown]
# Lemmatisation:

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmat=WordNetLemmatizer()
lem=list()
for word in data_tokens:
  lem.append(lemmat.lemmatize(word))
lem
# Out:
# ['I',
#  'chose',
#  'my',
#  'topic',
#  'to',
#  'be',
#  'the',
#  'Penguin',
#  'because',
#  ',',
#  'like',
#  'I',
#  'said',
#  ',',
#  'I',
#  'think',
#  'they',
#  'look',
#  'really',
#  'cute',
#  '.',
#  'I',
#  'think',
#  'they',
#  'look',
#  'really',
#  'cute',
#  'because',
#  'they',
#  'have',
#  'such',
#  'a',
#  'big',
#  'head',
#  'and',
#  'a',
#  'short',
#  ',',
#  'thick',
#  'neck',
#  '.',
#  'Also',
#  'the',
#  'way',
#  'they',
#  'waddle',
#  ',',
#  'is',
#  'really',
#  'cute',
#  '.',
#  'The',
#  'way',
#  'they',
#  'stand',
#  ',',
#  'really',
#  'fascinates',
#  'me',
#  '.',
#  'They',
#  'look',
#  'really',
#  'proud',
#  '.',
#  'I',
#  'sometimes',
#  'wish',
#  'I',
#  'wa',
#  'a',
#  'proud',
#  'a',
#  'they',
#  'look',
#  '.',
#  'Penguins',
#  'are',
#  'bird',
#  'that',
#  'ca',
#  "n't",
#  'fly',
#  ',',
#  'but',
#  'they',
#  'are',
#  'really',
#  'good',
#  'swimmer',
#  '.',
#  'This',
#  'mean',
#  'they',
# ...

# %% [markdown]
# Finding Frequency of Words exluding Stop-Words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.probability import FreqDist
stop_words = set(stopwords.words("english"))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
filtered=[]
for w in data_tokens:
  if w not in stop_words:
    if len(w)>3:
        w=w.lower()
        filtered.append(w)
        
fdist=FreqDist(filtered)
fdist
# Out:
# FreqDist({"'fly": 1,
#           'allows': 1,
#           'also': 3,
#           'animals': 2,
#           'antarctica': 1,
#           'appetites': 1,
#           'areas': 1,
#           'around': 1,
#           'babies': 2,
#           'back': 1,
#           'because': 2,
#           'become': 2,
#           'belly': 1,
#           'birds': 5,
#           'body': 2,
#           'bones': 1,
#           'bottom': 1,
#           'brood': 1,
#           'build': 2,
#           'called': 1,
#           'camouflage': 1,
#           'chose': 1,
#           'coat': 1,
#           'colour': 5,
#           'consist': 1,
#           'contain': 1,
#           'crustaceans': 1,
#           'cute': 3,
#           'dark': 2,
#           'darker': 1,
#           'dirt': 1,
#           'dive': 1,
#           'eggs': 3,
#           'emperor': 1,
#           'equator': 1,
#           'even': 1,
#           'fascinates': 1,
#           'feathers': 3,
#           'feed': 3,
#           'females': 1,
# ...

# %% [markdown]
# Entity and Facts Extraction

# %%
for entity in doc.ents:
    print(f"{entity.text} ({entity.label_})")
# Out:
# Penguins (ORG)
# Antarctica (LOC)
# thousands (CARDINAL)

# %%
statements = textacy.extract.semistructured_statements(doc, entity="Penguins",cue='be')


print("Here are the things I know about penguins:")

for statement in statements:
    subject, verb, fact = statement
    print(f" - {fact}")
# Out:
# Here are the things I know about penguins:
#  - [birds, that, ca, n't, fly]
#  - [very, social, birds]

# %% [markdown]
# NER

# %%
from nltk import ne_chunk

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
ne=ne_chunk(pos)
print(ne)
# Out:
# (S
#   I/PRP
#   chose/VBD
#   my/PRP$
#   topic/NN
#   to/TO
#   be/VB
#   the/DT
#   (ORGANIZATION Penguin/NNP)
#   because/IN
#   ,/,
#   like/IN
#   I/PRP
#   said/VBD
#   ,/,
#   I/PRP
#   think/VBP
#   they/PRP
#   look/VBP
#   really/RB
#   cute/JJ
#   ./.
#   I/PRP
#   think/VBP
#   they/PRP
#   look/VBP
#   really/RB
#   cute/JJ
#   because/IN
#   they/PRP
#   have/VBP
#   such/PDT
#   a/DT
#   big/JJ
#   head/NN
#   and/CC
#   a/DT
#   short/JJ
#   ,/,
#   thick/JJ
#   neck/NN
#   ./.
#   Also/RB
#   the/DT
#   way/NN
#   they/PRP
#   waddle/VBP
#   ,/,
#   is/VBZ
#   really/RB
#   cute/JJ
#   ./.
#   The/DT
#   way/NN
#   they/PRP
#   stand/VBP
#   ,/,
#   really/RB
#   fascinates/VBZ
#   me/PRP
#   ./.
#   They/PRP
#   look/VBP
#   really/RB
#   proud/JJ
#   ./.
#   I/PRP
#   sometimes/RB
#   wish/VBP
#   I/PRP
#   was/VBD
#   as/RB
#   proud/JJ
#   as/IN
#   they/PRP
#   look/VBP
#   ./.
#   Penguins/NNS
#   are/VBP
#   birds/NNS
#   that/WDT
#   ca/MD
#   n't/RB
# ...

# %% [markdown]
# Conclusion

# %%
#find 10 most frequent words
f10=fdist.most_common(10)
f10
# Out:
# [('penguins', 10),
#  ('penguin', 8),
#  ('really', 6),
#  ('birds', 5),
#  ('colour', 5),
#  ('look', 4),
#  ('they', 4),
#  ('skin', 4),
#  ('cute', 3),
#  ('short', 3)]
